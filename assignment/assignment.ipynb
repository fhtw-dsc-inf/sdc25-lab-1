# %% [markdown]
# ## Exercise 1:
# Review the guidelines for good data visualization again, then apply your knowledge to practical exercises.
#
# ### Part 1:
# - Load the CSV file `candy.csv` into a Pandas DataFrame.
# - Build interactive visualizations using one of the libraries mentioned or any other library of your choice. Possible libraries include Mercury, Voila, Bokeh, Dash,...
# - Experiment with different forms of presentation.
# - Implement a smart and intuitive way to communicate insights visually.
#
#
# ### Part 2:
# Build an **interactive** visualization for one of the following datasets using a library of your choice. Options include Mercury, Voila, Bokeh, Dash, or any other library:
#
# - `EnergyPrices`
# - `CO2data`
#
# Carry out the following steps:
# - Implement a smart and intuitive way to communicate and identify insights visually.
