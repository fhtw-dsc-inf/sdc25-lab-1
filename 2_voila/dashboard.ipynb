# %%
# libs required:
# !pip install -U ipywidgets voila widgets nbextension ipympl

# %%
# %matplotlib widget

# %%
import yfinance as yf
import ipywidgets as widgets
#import mplfinance as mpf
from matplotlib import pyplot as plt

# %% [markdown]
# Browse widget list to select widgets:
#
# https://ipywidgets.readthedocs.io/en/stable/examples/Widget%20List.html

# %%
ticker = widgets.Dropdown(
    options=['TSLA', 'AAPL', 'MSFT'],
    value='TSLA',
    description='Stock name:',
    disabled=False,
)

# %%
def load(change):
    history = yf.Ticker(ticker.value).history(period="3mo")
    pl = plt.plot(history.Open)

ticker.observe(load, names='value')

# %%
load(None)
# Out:
# /usr/local/python/3.12.1/lib/python3.12/site-packages/yfinance/utils.py:788: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
ticker
# Out:
# Dropdown(description='Stock name:', options=('TSLA', 'AAPL', 'MSFT'), value='TSLA')
